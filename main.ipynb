# %% [markdown]
# # Semi supervised learning for drug discovery
# ## 02456 Deep Learning Project: Group 21

# %% [markdown]
# This Jupyter notebook is a walkthrough. All implemented functions can be found in this repository.

# %% [markdown]
# ### Understanding the Dataset
#
# - Pre-processing
# - Feature-extraction
# - Data visualisation

# %%
# Insert code here

print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ### Graph Neural Network Architecture(s)? Semi-supervised learning
#
# - Implementation

# %%
# Insert code here

print("Hello, world!")
# Out:
# Hello, World!

# %% [markdown]
# ### Pooling? Results?
#
# - (y1 - ytilde) squared

# %%
# Insert code here

print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ### Evaluation of Model?
#
# - AUC, ROC for classification?
# - MSE for regression?

# %%
# Insert code here

print("Hello, world!")
# Out:
# Hello, world!
